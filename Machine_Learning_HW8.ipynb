# %% [markdown]
# <span style="font-size: 14pt">Домашнее задание №8 </span>
#
# <span style="color: red; font-size: 14pt">Deadline: 20.05.2017 23:59:59</span>
#
# <span style="font-size: 10pt">ФИВТ, АПТ, Курс по машинному обучению, Весна 2017, Модуль Unspervised Learning, </span>
#
# <span style="color:blue; font-size: 10pt">Alexey Romanenko, </span>
# <span style="color:blue; font-size: 10pt; font-family: 'Verdana'">alexromsput@gmail.com</span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Воронцов К. В. Математические методы обучения по прецедентам. 2012. http://www.machinelearning.ru/wiki/images/6/6d/Voron-ML-1.pdf (разделы 5.2 и 7.1)
# - Hastie T., Tibshirani R., Friedman J. The Elements of Statistical Learning. Springer: Data Mining, Inference, and Prediction.  — 2nd ed. — Springer-Verlag. 2009. — 746 p.http://statweb.stanford.edu/~tibs/ElemStatLearn/printings/ESLII_print10.pdf (глава 14)
#
#
#
# **Оформление дз**:
# - Присылайте выполненное задание на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_fall <номер_группы> <фамилия>``, к примеру -- ``ML2017_fall 496 ivanov``
# - Выполненное дз сохраните в файл ``<фамилия>_<группа>_task<номер задания>.ipnb``, к примеру -- ``ML2017_496_task1.ipnb``
#
# **Вопросы**:
# - Присылайте вопросы на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2016_fall Question <Содержание вопроса>``
#
# --------
# - **PS1**: Используются автоматические фильтры, и просто не найдем ваше дз, если вы не аккуратно его подпишите.
# - **PS2**: Дедлайн жесткий, в том числе помтоу что это ДЗ последнее в курсе.

# %% [markdown]
# <h1 align="center">Контрольные вопросы (0 % - для самоконтроля) </h1>

# %% [markdown]
# Ответе на вопросы своими словами (загугленный материал надо пересказать), ответ обоснуйте (напишите и ОБЪЯСНИТЕ формулки если потребуется), если не выходит, то вернитесь к лекции дополнительным материалам:
#
# **Вопрос 1**: В чём заключается проблема мультиколлинеарности?
#
# **Вопрос 2**: Какие проблемы при обучении алгоритмов возникают из-за большой разамерности пространства признаков?
#
# **Вопрос 3**: В чем суть проклятия размерности?
#
# ** Вопрос 4**: Какая связь между решением задачи PCA и SVD-разложение матрицы регрессии?
#
# ** Вопрос 5**: Почему в tSNE расстояние между парамми объектов измеряется "по-стьюденту" и как это помогает решить проблему "скрученности" (crowding problem)?
#
# **Вопрос 6**: На какой идее базируются алгоритмы аггломеративной кластеризации? Напишите формулу Ланса-Вильма
#
# **Вопрос 7**: Какие два шага выделяют в алгоритме кластеризации k-means?
#
# **Вопрос 8**: В чём отличия (основные упрощения) k-means от EM-алгоритма кластеризации?
#
# ** Вопрос 9 **Какой принцип работы графовых алгоритмов кластеризации?
#
# ** Вопрос 10 **  В чем некорректность постановки задачи кластеризации?
#
# -----------
# PS: Если проверяющий не понял ответ на большинство вопросов, то будет пичалька. Пишите так, чтобы можно было разобраться.

# %% [markdown]
# <h1 align="center">Вопросы по теории (30%) </h1>

# %% [markdown]
# ** Задача 1 **
# Ответьте на вопросы:
#
#  1) Как можно не прибегая к визуализации понять, что кластерная структура у данного облака точек отсутствует?
#
#  Запустим алгоритм кластеризации и оценим межкластерные и внутрикластерные расстояния. Обычно внутрикластерные расстояния меньше межкластерных. Запустим несколько алгоритмов и, собрав данную информацию, сделаем вывод о возможном числе кластеров или хотя бы конечном промежутке, которому принадлежит это число.
#
#  2) Какие из алгоритмов кластеризации могут выделять кластеры с ленточной структурой?
#
# DBSCAN, FOREL
#
#  3) Какие алгоритмы кластеризации чувствительны к шуму и перемычкам?
#
# Алгоритм кратчайшего незамкнутого пути, алгоритм выделения связных компонент
#
#  4) Каким образом приближают «центр кластера» в нелинейных пространствах?
#
# Будем брать в качестве нового центра тот объект, среднее расстояний до которого от других объектов минимальна.
#
#  5) Каким образом можно определять число кластеров?
#
#  1. Визуально
#  2. Алгоритм, описанный в вопросе 1.
# ** Задача 2 **
# Даны пять точек на числовой оси $X = (1; 5; 7; 8; 8)$, число кластеров равно 2. Рассчитайте ответ алгоритма  K-means (финальные центры кластеров), если начальные центры кластеров c1 = 1, c2 = 10.
#
# $\text{Кластер}_1 = \{1, 5\}\\
# \text{Кластер}_2 = \{7, 8, 8\} \\
# \text{Центры: } 3 \ и \ \frac{23}{3}$
#
# ** Задача 3 **
# Докажите, что the k-means всегда сходится.
#
# Так как точек конечное число, то существует конечное число разбиений пространства (число разбиений конечного множества конечно), а значит, алгоритм наверняка остановится, перебрав все возможные варианты разбиения.
# Почему алгоритм не зациклится? При выборе следующего центра алгоритм движется в сторону уменьшения (или хотя бы неувеличения) расстояния до ближайших точек, а значит, алгоритм никогда не сделает шаг назад и не зациклится.
#
# ** Задача 4 **
# Для сжатия размерности пространства алгоритм PCA применяется датасету с количеством признаков $D = 100$. Наблюдается следующий спектр собственных значений матрицы объектов-признаков.
# <img src="PCA_lambda.png" width="600">
# Ответье на вопросы
#
# * 1) Высокая ли эффективная размерность пространства признаков (intrinsic dimensionality) (насколько она близка к 100)?
#
# Да, высока. Посмотрим на $\sum_{n=1}^{100}{\lambda_n} \sim 135$. Даже напоследние $\lambda_i$ вносят в эту сумму влкад $\ge 0.5-0.7$ каждая. Предположим, что мы отбросили 10 последних слагаемых. По графику $\sum_{n=90}^{100}{\lambda_n} \sim 6 \Rightarrow$ потеря качества составит $\frac{6}{135} = 4.5\%$. То есть даже отбрасывание последних компонент приводит к ухудшению качества.
# * 2) Можно ли перевести датасет с помощью PCA в пространство меньшей размерности с минимальными потерями точности? Если да, то чему примерно будет равна размернось
#
#
# Судя по рассчетам выше, нет. Возможно, можно перевести в пространство размерности 90-95, однако выгода от такого преобразования сомнительна.

# %% [markdown]
# <h2 align="center">Практическое задание 1 (30%) </h2>
# Реализуйте PCA

# %%
import numpy as np
import pylab as plt
'''
Performs the Principal Coponent analysis of the Matrix F
Matrix must be n * l dimensions
where n is # features
l is # samples
'''

def PCA(F, varRetained = 0.95, show = False):
    # Input
    #     F - initaial matrix 
    # Compute Covariance Matrix Sigma
    # Input
    (n, l) = F.shape
    Sigma = 1.0 / l * np.dot(F.T, F)
    # Compute eigenvectors and eigenvalues of Sigma by SVD
    # U, V - matrix, d - array: Sigma = U * np.diag(d) * V
    
    U, d, V = np.linalg.svd(F.T)

    # compute the value m: number of minumum features that retains the given variance varRetaine
    dTot = np.sum(d)
    var_i = np.array([np.sum(d[: i + 1]) / \
                dTot * 100.0 for i in range(n)])
    m = np.argmax(var_i > varRetained*100)
    print '{}.2f %% variance retained in {} dimensions'.format(var_i[m], m)

    # plot the variance plot
    if show:
        plt.plot(var_i)
        plt.xlabel('Number of Features')
        plt.ylabel(' Percentage Variance retained')
        plt.title('PCA $\% \sigma^2 $ vs # features')
        plt.show()

    # compute the reduced dimensional features by projection
    U_reduced = V.T[:, :m]
    G = np.dot(F.T, U_reduced)

    return G, U_reduced

# %%
# Примените алгоритм к данным MNIST
from sklearn.model_selection import train_test_split

from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)
X_train, X_test, Y_train, Y_test = train_test_split(X, y, train_size=0.7)

# %%
#################################################################
# PCA of training set
print 'Performing PCA - Principal COmponent Analysis'

Z, U_reduced = PCA(X.T, varRetained = 0.95, show = True)
# Out:
# Performing PCA - Principal COmponent Analysis
# 95.0721370382.2f %% variance retained in 40 dimensions

# %%
print Z
print U_reduced
# Out:
# [[  4.58612772e+01  -1.19211574e+00   2.11000593e+01 ...,   2.77637672e+00
#     1.08339635e+00   2.79603567e-01]
#  [  5.55296793e+01   7.86176977e+00  -2.04871986e+01 ...,  -2.06566530e+00
#    -2.62347905e-01   7.24943377e-01]
#  [  5.58278837e+01   6.91459576e+00  -9.66245273e+00 ...,  -8.64029615e-03
#     1.03407080e+00   3.32564400e+00]
#  ...,
#  [  6.55269853e+01   1.06587286e+01  -6.29456080e+00 ...,  -1.17825609e+00
#     4.24475769e-01  -1.06720963e+00]
#  [  5.86061659e+01  -4.91125210e+00   1.27231523e+01 ...,   1.33324857e-01
#    -7.77839257e-01   5.10143077e-01]
#  [  6.44482310e+01  -4.55513470e-01   7.04184347e+00 ...,  -6.63237391e-01
#    -1.06715047e+00   4.76893855e+00]]
# [[  1.74588012e-18  -6.78969169e-19   1.31513399e-17 ...,   1.03367871e-16
#     4.13215196e-17   1.11846999e-17]
#  [  5.77192878e-03  -1.73619371e-02  -9.85740003e-03 ...,  -2.21436704e-02
#    -1.05228027e-02  -6.43467663e-02]
#  [  1.00696020e-01  -2.24200800e-01  -4.48071690e-02 ...,   6.98896788e-02
#    -9.96581450e-02   4.26297018e-02]
#  ...,
#  [  1.30885120e-01  -9.01286131e-02   1.83210572e-01 ...,  -2.30962509e-01
#     1.41460626e-01   6.24506251e-02]
#  [  3.92343661e-02  -3.68410903e-02   2.14953332e-02 ...,   1.38344245e-01
#    -9.35151632e-04  -6.75000370e-02]
#  [  6.76004954e-03  -1.15150706e-02  -6.40453868e-03 ...,   2.27469181e-01
#    -2.32599723e-02   3.22715072e-02]]

# %% [markdown]
# <h1 align="center"><h2 align="center">Практическое задание 2 (40%) </h2> </h1>

# %% [markdown]
# <h2 align="left">Изучение алгоритмов кластеризации на разных выборках</h2>
#
# ### Кластеризация цифр с помощью dbscan
# На данных из sklearn.datasets.load_digits примените алгоритмы кластеризации (знания о метках классов при кластеризации использовать нельзя):
#  - <a href='http://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html#sklearn.cluster.DBSCAN'>dbscan </a>
#  запускайте при различных параметрах eps и minsamples, для всех экспериментов можете выбрать одну метрику (вспомните семинар про  метрические алгоритмы);
#  - Используя метки классов цифр, оцените качество различных кластеризаций при помощи Adjusted Mutual Information и Adjusted Rand Index.
#  - визуалируйте изображения тех цифр, которые соответствуют core_points;
#  - визуалируйте изображения тех цифр, которые соответствуют выбросам;
#  - сделайте выводы и применимости алгоритмов.
#
# ### Уменьшение палитры изображения
#  - для <a href="https://thumbs.dreamstime.com/x/two-lorikeet-birds-2293918.jpg"> картинки </a>
# нужно уменьшить число цветов в палитре; для этого нужно выделить кластеры в пространстве RGB, объекты соответствуют пикселам изображения; после выделения кластеров,
# все пикселы, отнесенные в один кластер, заполняются одним цветом; этот цвет может быть центроидом соответствующего кластера, медианным цветом по кластеру.
#  - Попробуйте различные алгоритмы кластеризации:
#         -- KMeans
#         -- MeanShift
#         -- AgglomerativeClustering
#    Рассмотрите число кластеров K = 2, 3, 10, 20
#  - Для различных кластеризаций оцените и сравните потери от уменьшения цветов при помощи
# метрики <a href="http://scikit-image.org/docs/dev/api/skimage.measure.html"> SSIM</a>. Какой способ оказался лучшим?

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn import metrics
# %matplotlib inline

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits['data']
target = digits['target']
plt.imshow(X)

# %%
PCA_X = PCA().fit_transform(X)
transformedX = TSNE().fit_transform(PCA_X)

# %%
eps = np.linspace(1, 2, 10)
samp = np.linspace(8, 20, 13)
for epsilon in eps:
    for min_samples in samp:
        db = DBSCAN(eps=epsilon, min_samples=min_samples, n_jobs=-1).fit(transformedX)
        core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
        core_samples_mask[db.core_sample_indices_] = True
        labels = db.labels_

        # Number of clusters in labels, ignoring noise if present.
        n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
        result = (metrics.adjusted_rand_score(target, labels),
                  metrics.adjusted_mutual_info_score(target, labels))
        print "epsilon = " + str(epsilon)
        print "min_samples = " + str(min_samples)
        print "Estimated number of clusters: {}".format(n_clusters_)
        print "Adjusted Rand Index: {}".format(result[0])
        print "Adjusted Mutual Information: {}".format(result[1])
        print "*********************************************************************************"
# Out:
# epsilon = 1.0
# min_samples = 8.0
# Estimated number of clusters: 25
# Adjusted Rand Index: 0.769117650365
# Adjusted Mutual Information: 0.760470119019
# *********************************************************************************
# epsilon = 1.0
# min_samples = 9.0
# Estimated number of clusters: 24
# Adjusted Rand Index: 0.736403541699
# Adjusted Mutual Information: 0.741920922177
# *********************************************************************************
# epsilon = 1.0
# min_samples = 10.0
# Estimated number of clusters: 23
# Adjusted Rand Index: 0.721503573989
# Adjusted Mutual Information: 0.736892346235
# *********************************************************************************
# epsilon = 1.0
# min_samples = 11.0
# Estimated number of clusters: 25
# Adjusted Rand Index: 0.623322211451
# Adjusted Mutual Information: 0.689310626822
# *********************************************************************************
# epsilon = 1.0
# min_samples = 12.0
# Estimated number of clusters: 28
# Adjusted Rand Index: 0.521804351398
# Adjusted Mutual Information: 0.649029605806
# *********************************************************************************
# epsilon = 1.0
# min_samples = 13.0
# Estimated number of clusters: 34
# Adjusted Rand Index: 0.383750447306
# Adjusted Mutual Information: 0.59078853267
# *********************************************************************************
# epsilon = 1.0
# min_samples = 14.0
# Estimated number of clusters: 35
# Adjusted Rand Index: 0.295419796707
# Adjusted Mutual Information: 0.561478027053
# *********************************************************************************
# epsilon = 1.0
# min_samples = 15.0
# Estimated number of clusters: 36
# Adjusted Rand Index: 0.210447203267
# Adjusted Mutual Information: 0.530021803966
# *********************************************************************************
# epsilon = 1.0
# min_samples = 16.0
# Estimated number of clusters: 36
# Adjusted Rand Index: 0.139539178634
# Adjusted Mutual Information: 0.503680594149
# *********************************************************************************
# epsilon = 1.0
# min_samples = 17.0
# Estimated number of clusters: 36
# Adjusted Rand Index: 0.114325927964
# Adjusted Mutual Information: 0.490577409425
# *********************************************************************************
# epsilon = 1.0
# min_samples = 18.0
# Estimated number of clusters: 30
# Adjusted Rand Index: 0.0563019689703
# Adjusted Mutual Information: 0.46617875714
# *********************************************************************************
# epsilon = 1.0
# min_samples = 19.0
# Estimated number of clusters: 25
# Adjusted Rand Index: 0.0350465798519
# Adjusted Mutual Information: 0.379107259946
# *********************************************************************************
# epsilon = 1.0
# min_samples = 20.0
# Estimated number of clusters: 19
# Adjusted Rand Index: 0.0233805809405
# Adjusted Mutual Information: 0.28111982223
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 8.0
# Estimated number of clusters: 22
# Adjusted Rand Index: 0.796798607955
# Adjusted Mutual Information: 0.786400546254
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 9.0
# Estimated number of clusters: 24
# Adjusted Rand Index: 0.784528378401
# Adjusted Mutual Information: 0.772610669401
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 10.0
# Estimated number of clusters: 22
# Adjusted Rand Index: 0.774357595254
# Adjusted Mutual Information: 0.768884802394
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 11.0
# Estimated number of clusters: 22
# Adjusted Rand Index: 0.751757736709
# Adjusted Mutual Information: 0.755878771599
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 12.0
# Estimated number of clusters: 22
# Adjusted Rand Index: 0.741876671502
# Adjusted Mutual Information: 0.7498746556
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 13.0
# Estimated number of clusters: 21
# Adjusted Rand Index: 0.714043142217
# Adjusted Mutual Information: 0.738345805513
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 14.0
# Estimated number of clusters: 21
# Adjusted Rand Index: 0.637193200031
# Adjusted Mutual Information: 0.708766514017
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 15.0
# Estimated number of clusters: 25
# Adjusted Rand Index: 0.51604346572
# Adjusted Mutual Information: 0.653585047019
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 16.0
# Estimated number of clusters: 26
# Adjusted Rand Index: 0.434143686177
# Adjusted Mutual Information: 0.6266516358
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 17.0
# Estimated number of clusters: 29
# Adjusted Rand Index: 0.341078809863
# Adjusted Mutual Information: 0.590366372863
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 18.0
# Estimated number of clusters: 31
# Adjusted Rand Index: 0.239545854078
# Adjusted Mutual Information: 0.55215611538
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 19.0
# Estimated number of clusters: 33
# Adjusted Rand Index: 0.170394653685
# Adjusted Mutual Information: 0.521305852978
# *********************************************************************************
# epsilon = 1.11111111111
# min_samples = 20.0
# Estimated number of clusters: 33
# Adjusted Rand Index: 0.118602590832
# Adjusted Mutual Information: 0.498722650178
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 8.0
# Estimated number of clusters: 22
# Adjusted Rand Index: 0.801596950977
# Adjusted Mutual Information: 0.790799926542
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 9.0
# Estimated number of clusters: 22
# Adjusted Rand Index: 0.799247441335
# Adjusted Mutual Information: 0.788352033629
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 10.0
# Estimated number of clusters: 23
# Adjusted Rand Index: 0.78848442203
# Adjusted Mutual Information: 0.777396704325
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 11.0
# Estimated number of clusters: 21
# Adjusted Rand Index: 0.778497297444
# Adjusted Mutual Information: 0.773568766563
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 12.0
# Estimated number of clusters: 21
# Adjusted Rand Index: 0.775081683102
# Adjusted Mutual Information: 0.770795276575
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 13.0
# Estimated number of clusters: 19
# Adjusted Rand Index: 0.768813569605
# Adjusted Mutual Information: 0.772789867315
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 14.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.753470055113
# Adjusted Mutual Information: 0.773706786454
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 15.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.748566468904
# Adjusted Mutual Information: 0.771084210051
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 16.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.718837590563
# Adjusted Mutual Information: 0.752893577688
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 17.0
# Estimated number of clusters: 20
# Adjusted Rand Index: 0.677603577765
# Adjusted Mutual Information: 0.726969781706
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 18.0
# Estimated number of clusters: 23
# Adjusted Rand Index: 0.548472383994
# Adjusted Mutual Information: 0.672224325371
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 19.0
# Estimated number of clusters: 24
# Adjusted Rand Index: 0.45942219688
# Adjusted Mutual Information: 0.639324165988
# *********************************************************************************
# epsilon = 1.22222222222
# min_samples = 20.0
# Estimated number of clusters: 27
# Adjusted Rand Index: 0.349677292343
# Adjusted Mutual Information: 0.596994137495
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 8.0
# Estimated number of clusters: 21
# Adjusted Rand Index: 0.815879326191
# Adjusted Mutual Information: 0.80321577785
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 9.0
# Estimated number of clusters: 22
# Adjusted Rand Index: 0.807492463216
# Adjusted Mutual Information: 0.795898965308
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 10.0
# Estimated number of clusters: 21
# Adjusted Rand Index: 0.806392142393
# Adjusted Mutual Information: 0.795499848887
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 11.0
# Estimated number of clusters: 20
# Adjusted Rand Index: 0.804190678265
# Adjusted Mutual Information: 0.795106708509
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 12.0
# Estimated number of clusters: 20
# Adjusted Rand Index: 0.794297880426
# Adjusted Mutual Information: 0.787247194677
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 13.0
# Estimated number of clusters: 19
# Adjusted Rand Index: 0.780915707618
# Adjusted Mutual Information: 0.779958573864
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 14.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.773703549314
# Adjusted Mutual Information: 0.783544618734
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 15.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.768468075499
# Adjusted Mutual Information: 0.780796700101
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 16.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.761202351511
# Adjusted Mutual Information: 0.776532909189
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 17.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.756042796051
# Adjusted Mutual Information: 0.773950060908
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 18.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.745683342512
# Adjusted Mutual Information: 0.768826607024
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 19.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.720832075231
# Adjusted Mutual Information: 0.75920782418
# *********************************************************************************
# epsilon = 1.33333333333
# min_samples = 20.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.685913340075
# Adjusted Mutual Information: 0.751823778133
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 8.0
# Estimated number of clusters: 19
# Adjusted Rand Index: 0.837208353186
# Adjusted Mutual Information: 0.821392276028
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 9.0
# Estimated number of clusters: 19
# Adjusted Rand Index: 0.837208353186
# Adjusted Mutual Information: 0.821392276028
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 10.0
# Estimated number of clusters: 19
# Adjusted Rand Index: 0.835857615523
# Adjusted Mutual Information: 0.819715539154
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 11.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.835176048213
# Adjusted Mutual Information: 0.820271305336
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 12.0
# Estimated number of clusters: 19
# Adjusted Rand Index: 0.819991088756
# Adjusted Mutual Information: 0.80541694472
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 13.0
# Estimated number of clusters: 19
# Adjusted Rand Index: 0.791822091866
# Adjusted Mutual Information: 0.785892386732
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 14.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.779842950912
# Adjusted Mutual Information: 0.784348181393
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 15.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.775630921248
# Adjusted Mutual Information: 0.781813387729
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 16.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.774257428138
# Adjusted Mutual Information: 0.78232167295
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 17.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.772445481208
# Adjusted Mutual Information: 0.781346142112
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 18.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.768240734162
# Adjusted Mutual Information: 0.779021714417
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 19.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.767454594824
# Adjusted Mutual Information: 0.778981025688
# *********************************************************************************
# epsilon = 1.44444444444
# min_samples = 20.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.747878348541
# Adjusted Mutual Information: 0.782706462448
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 8.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.839069797506
# Adjusted Mutual Information: 0.825030168133
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 9.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.839069797506
# Adjusted Mutual Information: 0.825030168133
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 10.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.837633565397
# Adjusted Mutual Information: 0.822989430572
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 11.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.837008473026
# Adjusted Mutual Information: 0.823177517952
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 12.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.837008473026
# Adjusted Mutual Information: 0.823177517952
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 13.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.826511177925
# Adjusted Mutual Information: 0.814941298362
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 14.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.812766697761
# Adjusted Mutual Information: 0.810787655214
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 15.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.812766697761
# Adjusted Mutual Information: 0.810787655214
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 16.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.809697748502
# Adjusted Mutual Information: 0.809409780275
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 17.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.808190224842
# Adjusted Mutual Information: 0.808685953711
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 18.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.80024630462
# Adjusted Mutual Information: 0.799611145868
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 19.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.796919605473
# Adjusted Mutual Information: 0.797030934831
# *********************************************************************************
# epsilon = 1.55555555556
# min_samples = 20.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.791221874804
# Adjusted Mutual Information: 0.801859404904
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 8.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.838809712456
# Adjusted Mutual Information: 0.826534904718
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 9.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.838809712456
# Adjusted Mutual Information: 0.826534904718
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 10.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.839246932806
# Adjusted Mutual Information: 0.826088741465
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 11.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839244199124
# Adjusted Mutual Information: 0.826312477058
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 12.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.838101258069
# Adjusted Mutual Information: 0.824549077982
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 13.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.838084545645
# Adjusted Mutual Information: 0.824541706641
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 14.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.830736170597
# Adjusted Mutual Information: 0.818582141921
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 15.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.818640882923
# Adjusted Mutual Information: 0.816286206925
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 16.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.815536149475
# Adjusted Mutual Information: 0.813596100099
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 17.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.815536149475
# Adjusted Mutual Information: 0.813596100099
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 18.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.813911218242
# Adjusted Mutual Information: 0.811866046076
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 19.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.812372998747
# Adjusted Mutual Information: 0.811161852034
# *********************************************************************************
# epsilon = 1.66666666667
# min_samples = 20.0
# Estimated number of clusters: 14
# Adjusted Rand Index: 0.806511696729
# Adjusted Mutual Information: 0.813782396588
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 8.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.838809712456
# Adjusted Mutual Information: 0.826534904718
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 9.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.838809712456
# Adjusted Mutual Information: 0.826534904718
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 10.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.839336422701
# Adjusted Mutual Information: 0.826342523382
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 11.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.838968982464
# Adjusted Mutual Information: 0.826009797108
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 12.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.83940720326
# Adjusted Mutual Information: 0.826613007903
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 13.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839727725067
# Adjusted Mutual Information: 0.827151048277
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 14.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.834470383176
# Adjusted Mutual Information: 0.822432890669
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 15.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.834470383176
# Adjusted Mutual Information: 0.822432890669
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 16.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.825770240614
# Adjusted Mutual Information: 0.817288518645
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 17.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.817790977701
# Adjusted Mutual Information: 0.814790193125
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 18.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.817790977701
# Adjusted Mutual Information: 0.814790193125
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 19.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.81724520271
# Adjusted Mutual Information: 0.814355825917
# *********************************************************************************
# epsilon = 1.77777777778
# min_samples = 20.0
# Estimated number of clusters: 14
# Adjusted Rand Index: 0.813265716219
# Adjusted Mutual Information: 0.816642851668
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 8.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.839586738796
# Adjusted Mutual Information: 0.827335672985
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 9.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.839586738796
# Adjusted Mutual Information: 0.827335672985
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 10.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.839586738796
# Adjusted Mutual Information: 0.827335672985
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 11.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839782785468
# Adjusted Mutual Information: 0.826837219272
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 12.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839782785468
# Adjusted Mutual Information: 0.826837219272
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 13.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839782785468
# Adjusted Mutual Information: 0.826837219272
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 14.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.838566823341
# Adjusted Mutual Information: 0.825804614654
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 15.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.836808523059
# Adjusted Mutual Information: 0.824143553412
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 16.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.836808523059
# Adjusted Mutual Information: 0.824143553412
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 17.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.836808523059
# Adjusted Mutual Information: 0.824143553412
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 18.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.829887246254
# Adjusted Mutual Information: 0.82045248656
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 19.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.828944675585
# Adjusted Mutual Information: 0.819184940971
# *********************************************************************************
# epsilon = 1.88888888889
# min_samples = 20.0
# Estimated number of clusters: 14
# Adjusted Rand Index: 0.823861953908
# Adjusted Mutual Information: 0.825415247276
# *********************************************************************************
# epsilon = 2.0
# min_samples = 8.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.808227747452
# Adjusted Mutual Information: 0.823963706218
# *********************************************************************************
# epsilon = 2.0
# min_samples = 9.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.840538599953
# Adjusted Mutual Information: 0.828607210048
# *********************************************************************************
# epsilon = 2.0
# min_samples = 10.0
# Estimated number of clusters: 18
# Adjusted Rand Index: 0.839586738796
# Adjusted Mutual Information: 0.827335672985
# *********************************************************************************
# epsilon = 2.0
# min_samples = 11.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839286321743
# Adjusted Mutual Information: 0.827051414527
# *********************************************************************************
# epsilon = 2.0
# min_samples = 12.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839286321743
# Adjusted Mutual Information: 0.827051414527
# *********************************************************************************
# epsilon = 2.0
# min_samples = 13.0
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839782785468
# Adjusted Mutual Information: 0.826837219272
# *********************************************************************************
# epsilon = 2.0
# min_samples = 14.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.838657446254
# Adjusted Mutual Information: 0.825965709421
# *********************************************************************************
# epsilon = 2.0
# min_samples = 15.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.838657446254
# Adjusted Mutual Information: 0.825965709421
# *********************************************************************************
# epsilon = 2.0
# min_samples = 16.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.838657446254
# Adjusted Mutual Information: 0.825965709421
# *********************************************************************************
# epsilon = 2.0
# min_samples = 17.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.838657446254
# Adjusted Mutual Information: 0.825965709421
# *********************************************************************************
# epsilon = 2.0
# min_samples = 18.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.838323650915
# Adjusted Mutual Information: 0.82573611256
# *********************************************************************************
# epsilon = 2.0
# min_samples = 19.0
# Estimated number of clusters: 16
# Adjusted Rand Index: 0.838323650915
# Adjusted Mutual Information: 0.82573611256
# *********************************************************************************
# epsilon = 2.0
# min_samples = 20.0
# Estimated number of clusters: 15
# Adjusted Rand Index: 0.836294025338
# Adjusted Mutual Information: 0.826446495552
# *********************************************************************************

# %%
epsilon = 2
min_samples = 11
db = DBSCAN(eps=epsilon, min_samples=min_samples, n_jobs=-1).fit(transformedX)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
result = (metrics.adjusted_rand_score(target, labels),
          metrics.adjusted_mutual_info_score(target, labels))
print "Best result:"
print "epsilon = " + str(epsilon)
print "min_samples = " + str(min_samples)
print "Estimated number of clusters: {}".format(n_clusters_)
print "Adjusted Rand Index: {}".format(result[0])
print "Adjusted Mutual Information: {}".format(result[1])
# Out:
# Best result:
# epsilon = 2
# min_samples = 11
# Estimated number of clusters: 17
# Adjusted Rand Index: 0.839286321743
# Adjusted Mutual Information: 0.827051414527

# %%
unique_labels = set(labels)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
plt.figure(figsize=(8, 8))

for lab, color in zip(unique_labels, colors):
    class_member_mask = (labels == lab)

    xy = transformedX[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=color,
            markeredgecolor='k', markersize=10)
    xy = transformedX[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=color,
            markeredgecolor='k', markersize=5, label=lab)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/lines.py:1145: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markerfacecolor != fc:

# %%
import random

for lab in set(labels):
    plt.figure(figsize=(12, 1))
    class_member_mask = (labels == lab)
    if lab == -1:
        print('noise')
        images = random.sample(list(X[class_member_mask]), min(10, len(list(X[class_member_mask]))))
    else:
        print('core points of {} cluster'.format(lab))
        images = random.sample(list(X[class_member_mask & core_samples_mask]), 10)
    for j, image in enumerate(images):
        plt.subplot(1, 10, j + 1)
        plt.imshow(image.reshape((8, 8)), cmap='binary')
        plt.grid(True)
    plt.show()
# Out:
# core points of 0 cluster
# core points of 1 cluster
# core points of 2 cluster
# core points of 3 cluster
# core points of 4 cluster
# core points of 5 cluster
# core points of 6 cluster
# core points of 7 cluster
# core points of 8 cluster
# core points of 9 cluster
# core points of 10 cluster
# core points of 11 cluster
# core points of 12 cluster
# core points of 13 cluster
# core points of 14 cluster
# core points of 15 cluster
# core points of 16 cluster
# noise
